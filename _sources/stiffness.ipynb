# %% [markdown]
# # Assessing the Stiffness of a Network

# %% [markdown]
# Reaction networks with a wide range of rate timescales can be stiff, generally requiring implicit integrators.  Sometimes there might be only a single rate that is responsible for the stiffness, and in this case, it might be possible to do an approximation to alleviate some of the stiffness.
#
# Here we look at how to characterize the stiffness of the rate.

# %% [markdown]
# For a network of the form:
#
# $$\frac{d{\bf Y}}{dt} = {\bf f}({\bf Y})$$
#
# We construct the Jacobian as:
#
# $${\bf J} = \frac{\partial \dot{\bf Y}}{\partial {\bf Y}}$$
#
# If we compute the eigenvalues $\lambda_i$, of ${\bf J}$, then a stiff reaction network is characterized by:
#
# $$\frac{\max_i\{|\lambda_i|\}}{\min_i\{|\lambda_i|\}} \gg 1$$
#
# and related concept is the [spectral radius](https://en.wikipedia.org/wiki/Spectral_radius):
#
# $$\rho({\bf J}) = \max_i\{|\lambda_i|\}$$
#
# Some integrators (like Runge-Kutta-Chebyshev) use this to determine the number of stages needed for each integration
# step.

# %% [markdown]
# In pynucastro, the spectral radius of a network can be computed using {py:func}`spectral_radius <pynucastro.networks.rate_collection.RateCollection.spectral_radius>`.

# %%
import pynucastro as pyna

# %% [markdown]
# ## H burning network example

# %% [markdown]
# We'll create a network with the nuclei needed for various p-p and CNO burning sequences, as well as breakout.

# %%
all_nuclei = ["p", "h2", "he3", "he4",
              "li6", "li7", "be7", "be8", "b8",
              "c12", "c13", "n13", "n14", "n15",
              "o14", "o15", "o16", "o17", "o18",
              "f17", "f18", "f19",
              "ne18", "ne19", "ne20", "ne21"]

# %%
net = pyna.network_helper(all_nuclei, tabular_ordering=["ffn", "oda"],
                          verbose=False)

# %%
fig = net.plot(node_size=500, node_font_size=10)

# %% [markdown]
# ## Spectral radius

# %% [markdown]
# Now we'll choose conditions appropriate to the base of the convective H-burning envelope in a classical nova.

# %% [markdown]
# ```{important}
# The spectral radius will depend somewhat on the composition of the trace nuclei, so they should be varied in any analysis to cover what would be expected in a simulation.
# ```

# %%
rho = 1700
T = 7.e7
comp = pyna.Composition(net.unique_nuclei)
comp.set_all(1.e-6)
comp.set_nuc("h1", 0.7)
comp.set_nuc("he4", 0.28)
comp.set_nuc("n14", 0.02)
comp.normalize()

# %%
fig = comp.plot(trace_threshold=0.01)

# %% [markdown]
# If we evaluate the spectral radius, we see that it is reasonably large.

# %%
sprad = net.spectral_radius(rho, T, comp)
sprad
# Out:
# np.float64(345703.34445394564)

# %% [markdown]
# ## Alleviating stiffness

# %% [markdown]
# We can try to understand which rate is responble for making the spectral radius large by looping over each rate and recomputing the spectral radius without that rate included.  This is done by {py:func}`find_stiffest_rate <pynucastro.networks.rate_collection.RateCollection.find_stiffest_rate>`.

# %%
r = net.find_stiffest_rate(rho, T, comp)
print(r)
# Out:
# Li6 + p ⟶ He4 + He3

# %% [markdown]
# From here we see that it is just the ${}^6\mathrm{Li}(\mathrm{p},{}^3\mathrm{He}){}^4\mathrm{He}$ rate that is responsible.  Removing that rate drops the spectral radius by almost $50\times$:

# %%
sprad = net.spectral_radius(rho, T, comp, exclude_rates=[r])
sprad
# Out:
# np.float64(7094.285320878137)

# %% [markdown]
# We can look at all the rates that involve ${}^6\mathrm{Li}$ and see how fast they are:

# %%
rates = net.evaluate_rates(rho, T, comp)
# Out:
# /home/zingale/development/pynucastro/pynucastro/rates/derived_rate.py:120: UserWarning: He3 partition function is not supported by tables: set log_pf = 0.0 by default
#   warnings.warn(UserWarning(f'{nuc} partition function is not supported by tables: set log_pf = 0.0 by default'))
# /home/zingale/development/pynucastro/pynucastro/rates/derived_rate.py:120: UserWarning: d partition function is not supported by tables: set log_pf = 0.0 by default
#   warnings.warn(UserWarning(f'{nuc} partition function is not supported by tables: set log_pf = 0.0 by default'))
# /home/zingale/development/pynucastro/pynucastro/rates/derived_rate.py:120: UserWarning: Li6 partition function is not supported by tables: set log_pf = 0.0 by default
#   warnings.warn(UserWarning(f'{nuc} partition function is not supported by tables: set log_pf = 0.0 by default'))
# /home/zingale/development/pynucastro/pynucastro/rates/derived_rate.py:120: UserWarning: Be7 partition function is not supported by tables: set log_pf = 0.0 by default
#   warnings.warn(UserWarning(f'{nuc} partition function is not supported by tables: set log_pf = 0.0 by default'))
# /home/zingale/development/pynucastro/pynucastro/rates/derived_rate.py:120: UserWarning: B8 partition function is not supported by tables: set log_pf = 0.0 by default
#   warnings.warn(UserWarning(f'{nuc} partition function is not supported by tables: set log_pf = 0.0 by default'))
# /home/zingale/development/pynucastro/pynucastro/rates/derived_rate.py:120: UserWarning: C12 partition function is not supported by tables: set log_pf = 0.0 by default
#   warnings.warn(UserWarning(f'{nuc} partition function is not supported by tables: set log_pf = 0.0 by default'))
# /home/zingale/development/pynucastro/pynucastro/rates/derived_rate.py:120: UserWarning: N13 partition function is not supported by tables: set log_pf = 0.0 by default
#   warnings.warn(UserWarning(f'{nuc} partition function is not supported by tables: set log_pf = 0.0 by default'))
# /home/zingale/development/pynucastro/pynucastro/rates/derived_rate.py:120: UserWarning: C13 partition function is not supported by tables: set log_pf = 0.0 by default
#   warnings.warn(UserWarning(f'{nuc} partition function is not supported by tables: set log_pf = 0.0 by default'))
# /home/zingale/development/pynucastro/pynucastro/rates/derived_rate.py:120: UserWarning: N14 partition function is not supported by tables: set log_pf = 0.0 by default
#   warnings.warn(UserWarning(f'{nuc} partition function is not supported by tables: set log_pf = 0.0 by default'))
# /home/zingale/development/pynucastro/pynucastro/rates/derived_rate.py:120: UserWarning: N15 partition function is not supported by tables: set log_pf = 0.0 by default
#   warnings.warn(UserWarning(f'{nuc} partition function is not supported by tables: set log_pf = 0.0 by default'))
# /home/zingale/development/pynucastro/pynucastro/rates/derived_rate.py:120: UserWarning: Li7 partition function is not supported by tables: set log_pf = 0.0 by default
#   warnings.warn(UserWarning(f'{nuc} partition function is not supported by tables: set log_pf = 0.0 by default'))

# %%
for r in net.get_rates():
    if pyna.Nucleus("li6") in r.reactants + r.products:
        print(r, rates[r])
# Out:
# H2 + He4 ⟶ Li6 + 𝛾 6.902655749081773e-11
# Li6 + p ⟶ Be7 + 𝛾 1.9335397883565184e-06
# Li6 + p ⟶ He4 + He3 0.0576139258675003
# Li6 + H2 ⟶ p + Li7 2.5784505974031287e-08
# Li6 ⟶ He4 + H2 4.3184914250259065e-111
# Be7 ⟶ p + Li6 0.0
# He3 + He4 ⟶ p + Li6 4.841408890769728e-292
# Li7 + p ⟶ H2 + Li6 0.0

# %% [markdown]
# This shows that the same rate responsible for increasing the spectral radius is also the fastest rate involving ${}^6\mathrm{Li}$.

# %% [markdown]
# At this stage, there are a few paths that can be taken.

# %% [markdown]
# Based on the rate strengths, we might not ever need to consider ${}^4\mathrm{He}(\mathrm{d}, \gamma){}^6\mathrm{Li}$, which removes the production of ${}^6\mathrm{Li}$ from the network completely, so we could just remove that nucleus.  This would be reasonable if there were something else that consumes $\mathrm{d}$ much faster.  Let's see:

# %%
for r in net.get_rates():
    if pyna.Nucleus("d") in r.reactants:
        print(r, rates[r])
# Out:
# H2 + p ⟶ He3 + 𝛾 0.0013628129288238144
# H2 + H2 ⟶ He4 + 𝛾 1.7810027635650437e-12
# H2 + He4 ⟶ Li6 + 𝛾 6.902655749081773e-11
# He3 + H2 ⟶ p + He4 3.117040364361626e-06
# Li6 + H2 ⟶ p + Li7 2.5784505974031287e-08
# Be7 + H2 ⟶ p + He4 + He4 6.126324691465521e-11

# %% [markdown]
# Most of these rates are much faster than ${}^4\mathrm{He}(\mathrm{d}, \gamma){}^6\mathrm{Li}$, so it does seem reasonable that we can just remove that nucleus.

# %% [markdown]
# Alternately, we can approximate out ${}^6\mathrm{Li}$ by assuming equilibrium of the 4 rates listed above, setting:
#
# $$\frac{dY({}^6\mathrm{Li})}{dt} = 0$$
#
# and then write effective rates that link to ${}^7\mathrm{Li}$ and ${}^7\mathrm{Be}$.
